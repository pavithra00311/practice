# %%
name = "pavithra"
age = 22
is_student = True

# %%
is_student
name
# Out:
# 'pavithra'

# %%
is_student = False
is_student
# Out:
# False

# %%
print(name)
print(age)
# Out:
# pavithra
# 22

# %%
2 ** 3
# Out:
# 8

# %%
6 - 6
# Out:
# 0

# %%
2 * 3
# Out:
# 6

# %%
5 == 5
# Out:
# True

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
print(5 != 5)
print(5 > 5)
print(5 <=10)
# Out:
# False
# False
# True

# %%
x = 10
y =6
print(x>y and x<y)
# Out:
# False

# %%
c="pavithra"
d="praveen"
print(c=="pavithra" or d=="pavithra" )
# Out:
# True

# %%
c = 29
f=89
print(c != 29)
# Out:
# False

# %% [markdown]
# # variable
